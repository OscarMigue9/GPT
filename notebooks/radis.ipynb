# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
radis_ch4 =np.load("C:\\Users\\PC\\Documents\\GitHub\\Photonix\\out\\OUT_RADIS\\Simulated_CH4.npy")

# %%
plt.plot(radis_ch4[0], radis_ch4[1])

# %%
lsf_ch4 = np.load("C:\\Users\\PC\\Documents\\GitHub\\Photonix\\out\\OUT_RADIS\\Simulated_CH4_lsf.npy")
plt.plot(lsf_ch4[0], lsf_ch4[1])

# %%
profe_ch4 =np.load("C:\\Users\\PC\\Documents\\GitHub\\Photonix\\gt_profe\\CH4_4-10.npy")
plt.plot(profe_ch4[0], profe_ch4[1])
