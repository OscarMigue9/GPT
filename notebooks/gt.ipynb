# %%
import importlib
import numpy as np
import final_forward_attenuation
importlib.reload(final_forward_attenuation)
from final_forward_attenuation import run_simulation, default_species, convert_atm, txt_to_npy, convert_vmr, plot_npy, plot_histogram, count_lines_by_index

# %%
# '''Convirtiendo .txts a .npys'''
# txt_to_npy('GT_PROFE_TXT/CH4_10-30.txt','GT_PROFE/CH4_10-30')
# txt_to_npy('GT_PROFE_TXT/CO_4-10.txt','GT_PROFE/CO_4-10')
# txt_to_npy('GT_PROFE_TXT/CO_10-30.txt','GT_PROFE/CO_10-30')
# txt_to_npy('GT_PROFE_TXT/N2O_4-10.txt','GT_PROFE/N2O_4-10')
# txt_to_npy('GT_PROFE_TXT/N2O_10-30.txt','GT_PROFE/N2O_10-30')
# txt_to_npy('GT_PROFE_TXT/O3_4-10um_1m.txt','GT_PROFE/O3_4-10um_1m')
# txt_to_npy('GT_PROFE_TXT/O3_10-30um_1m.txt','GT_PROFE/O3_10-30um_1m')
# txt_to_npy('GT_PROFE_TXT/Transmittance_Standard_CO2_4-10_1m.txt','GT_PROFE/Transmittance_Standard_CO2_4-10_1m')
# txt_to_npy('GT_PROFE_TXT/Transmittance_Standard_CO2_10-30_1m.txt','GT_PROFE/Transmittance_Standard_CO2_10-30_1m')
# txt_to_npy('GT_PROFE_TXT/Transmittance_Standard_H2O_4-10_1m.txt','GT_PROFE/Transmittance_Standard_H2O_4-10_1m')
# txt_to_npy('GT_PROFE_TXT/Transmittance_Standard_H2O_10-30_1m.txt','GT_PROFE/Transmittance_Standard_H2O_10-30_1m')

# %%
'''CH4 4-10'''
wave, tr = np.load('GT_PROFE/CH4_4-10.npy')
name = 'CH4 4-10'
plot_npy(wave, tr, name=name)
plot_histogram(wave, name=name)

# %%
'''CH4 10-30'''
wave, tr = np.load('GT_PROFE/CH4_10-30.npy')
name = 'CH4 10-30'
plot_npy(wave, tr, name=name)
plot_histogram(wave, name=name, bins=150)

# %%
'''CO 4-10'''
wave, tr = np.load('GT_PROFE/CO_4-10.npy')
name = 'CO 4-10'
plot_npy(wave, tr, name=name)
plot_histogram(wave, name=name)

# %%
'''CO 10-30'''
wave, tr = np.load('GT_PROFE/CO_10-30.npy')
name = 'CO 10-30'
plot_npy(wave, tr, name=name)
plot_histogram(wave, name=name, bins=150)

# %%
'''N2O 4-10'''
wave, tr = np.load('GT_PROFE/N2O_4-10.npy')
name = 'N2O 4-10'
plot_npy(wave, tr, name=name)
plot_histogram(wave, name=name)

# %%
'''N2O 10-30'''
wave, tr = np.load('GT_PROFE/N2O_10-30.npy')
name = 'N2O 10-30'
plot_npy(wave, tr, name=name)
plot_histogram(wave, name=name, bins=150)

# %%
'''O3 4-10'''
wave, tr = np.load('GT_PROFE/O3_4-10um_1m.npy')
name = 'O3 4-10'
plot_npy(wave, tr, name=name)
plot_histogram(wave, name=name)

# %%
'''O3 10-30'''
wave, tr = np.load('GT_PROFE/O3_10-30um_1m.npy')
name = 'O3 10-30'
plot_npy(wave, tr, name=name)
plot_histogram(wave, name=name, bins=150)

# %%
'''CO2 4-10'''
wave, tr = np.load('GT_PROFE/Transmittance_Standard_CO2_4-10_1m.npy')
name = 'CO2 4-10'
plot_npy(wave, tr, name=name)
plot_histogram(wave, name=name)

# %%
'''CO2 10-30'''
wave, tr = np.load('GT_PROFE/Transmittance_Standard_CO2_10-30_1m.npy')
name = 'CO2 10-30'
plot_npy(wave, tr, name=name)
plot_histogram(wave, name=name, bins=150)

# %%
'''H2O 4-10'''
wave, tr = np.load('GT_PROFE/Transmittance_Standard_H2O_4-10_1m.npy')
name = 'H2O 4-10'
plot_npy(wave, tr, name=name)
plot_histogram(wave, name=name)

# %%
Ptotal = convert_atm(1013, "mbar")
T = 288.2

sp = default_species()
for s in sp:
     if s.name == 'H2O': s.Pmol = 0.0187553713298791
     if s.name == 'CO2': s.Pmol = 0.0003299185788304959
     if s.name == 'O3': s.Pmol = 3.016255613126079e-08
     if s.name == 'N2O': s.Pmol = 3.1992104613866274e-07
     if s.name == 'CO': s.Pmol = 1.4996299037749815e-07
     if s.name == 'CH4': s.Pmol = 1.6995805576116458e-06
     if s.name == 'O2': s.Pmol = 0.2089484332593141
    

import os
print(os.getcwd())

res = run_simulation(
    species=sp,
    parfile='PARS/ALL.par',
    nu_min=700, nu_max=2500, dnu=0.01,
    tileW=20.0, guard=5.0,
    temp_K=T, L_m=1.0, pres=Ptotal,
    delta_um=0.020,
    save_csv=True, outdir='OUT', make_plots=True, 
    att=False, transmission_npy_name='Prueba_Isotopologos.npy',
    use_all_isotopologues=True, species_to_use=['H2O']

)

lambda_um = res['lambda_centers']
Tprod = res['T_prod_samp']
Tco2  = res['T_each_samp'][0]
# Out:
# c:\Users\PC\Desktop\UIS\Handson\Stand-off\FORWARD
# Using species: ['H2O']
# DEBUG: H2O iso=1 qfile=TIPS/H2O/q1.txt exists=True
# DEBUG: H2O iso=2 qfile=TIPS/H2O/q2.txt exists=True
# DEBUG: H2O iso=3 qfile=TIPS/H2O/q3.txt exists=True
# DEBUG: H2O iso=4 qfile=TIPS/H2O/q4.txt exists=True
# DEBUG: H2O iso=5 qfile=TIPS/H2O/q5.txt exists=True
# DEBUG: H2O iso=6 qfile=TIPS/H2O/q6.txt exists=True
# DEBUG: H2O iso=7 qfile=TIPS/H2O/q129.txt exists=True
# c:\Users\PC\Desktop\UIS\Handson\Stand-off\FORWARD\final_forward_attenuation.py:228: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(qfile, header=None, delim_whitespace=True, comment='#')
# c:\Users\PC\Desktop\UIS\Handson\Stand-off\FORWARD\final_forward_attenuation.py:228: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
# ...

# %%
x = np.load('SIMULATED/Prueba_Isotopologos.npy')
len(x[0])
# Out:
# 513

# %%
w, t = np.load('GT_PROFE/Transmittance_Standard_H2O_4-10_1m.npy')
len(w)
# Out:
# 644299

# %%
'''H2O 10-30'''
wave, tr = np.load('GT_PROFE/Transmittance_Standard_H2O_10-30_1m.npy')
name = 'H2O 10-30'
plot_npy(wave, tr, name=name)
plot_histogram(wave, name=name, bins=150)

# %%
len(wave)
# Out:
# 644299

# %%
'''CO2 4-10 simulacion'''
vmr = 0.00033 
Ptotal = convert_atm(1013, "mbar")
T = 288.2
Pco2 = vmr * Ptotal

sp = default_species()
for s in sp:
     s.Pmol = Pco2 if s.name == 'CO2' else 0

co2 = [s for s in sp if s.name == "CO2"]

import os
print(os.getcwd())

res = run_simulation(
    parfile='PARS/7Mols_1Iso.par',
    species=co2,
    nu_min=1000, nu_max=2500, dnu=0.01,
    tileW=20.0, guard=5.0,
    temp_K=T, L_m=1.0, pres=Ptotal,
    delta_um=0.020,
    save_csv=True, outdir='OUT', make_plots=False, 
    att=False, transmission_npy_name='Transmittance_Standard_CO2_4-10_1m.npy',
    use_all_isotopologues=True

)

lambda_um = res['lambda_centers']
Tprod = res['T_prod_samp']
Tco2  = res['T_each_samp'][0]
# Out:
# c:\Users\PC\Documents\GitHub\Stand-off
# DEBUG: CO2 qfile=TIPS/q7.txt exists=True
# c:\Users\PC\Documents\GitHub\Stand-off\final_forward_attenuation.py:99: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(qfile, header=None, delim_whitespace=True, comment='#')

# %%
w = np.load('SIMULATED/Transmittance_Standard_CO2_4-10_1m.npy')
wave, tr = np.load('GT_PROFE/Transmittance_Standard_CO2_4-10_1m.npy')
name = 'CO2 4-10'
plot_npy(wave, tr, name=name)
plot_npy(w[0], w[1], name='CO2 4-10 Simulated')

# %%
plot_histogram(wave, name=name)
plot_histogram(w[0], name='CO2 4-10 Simulated')

# %%
print("Cantiidad de puntos gt:", len(wave))
print("Cantidad de puntos simulados:", len(w[0]))
# Out:
# Cantiidad de puntos gt: 644299
# Cantidad de puntos simulados: 299

# %%
count_lines_by_index('PARS/7Mols_1Iso.par', 2)  # CO2
# Out:
# 159324

# %%
count_lines_by_index('PARS/CO2_4-10_1Iso.par', 2)  # CO2
# Out:
# 35683

# %%
count_lines_by_index('PARS/CO2_4-10_All_Iso.par', 2)  # CO2
# Out:
# 417277

# %%
'''CO2 4-10 simulacion'''
vmr = 0.00033 
Ptotal = convert_atm(1013, "mbar")
T = 288.2
Pco2 = vmr * Ptotal

sp = default_species()
for s in sp:
     s.Pmol = Pco2 if s.name == 'CO2' else 0

co2 = [s for s in sp if s.name == "CO2"]

import os
print(os.getcwd())

res = run_simulation(
    species=co2,
    parfile='PARS/ALL.par',
    nu_min=1000, nu_max=2500, dnu=0.01,
    tileW=20.0, guard=5.0,
    temp_K=T, L_m=1.0, pres=Ptotal,
    delta_um=0.020,
    save_csv=True, outdir='OUT', make_plots=True, 
    att=False, transmission_npy_name='Prueba_Sin_Isotopologos_CO2.npy',
    use_all_isotopologues=False

)

lambda_um = res['lambda_centers']
Tprod = res['T_prod_samp']
Tco2  = res['T_each_samp'][0]
# Out:
# c:\Users\PC\Desktop\UIS\Handson\Stand-off\FORWARD
# DEBUG: CO2 iso=1 qfile=TIPS/CO2/q7.txt exists=True
# c:\Users\PC\Desktop\UIS\Handson\Stand-off\FORWARD\final_forward_attenuation.py:217: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(qfile, header=None, delim_whitespace=True, comment='#')

# %%
'''CO2 4-10 simulacion'''
vmr = 0.00033 
Ptotal = convert_atm(1013, "mbar")
T = 288.2
Pco2 = vmr * Ptotal

sp = default_species()
for s in sp:
     s.Pmol = Pco2 if s.name == 'CO2' else 0

co2 = [s for s in sp if s.name == "CO2"]

import os
print(os.getcwd())

res = run_simulation(
    species=co2,
    parfile='PARS/ALL.par',
    nu_min=1000, nu_max=2500, dnu=0.01,
    tileW=20.0, guard=5.0,
    temp_K=T, L_m=1.0, pres=Ptotal,
    delta_um=0.020,
    save_csv=True, outdir='OUT', make_plots=True, 
    att=False, transmission_npy_name='Prueba_Isotopologos_CO2.npy',
    use_all_isotopologues=True

)

lambda_um = res['lambda_centers']
Tprod = res['T_prod_samp']
Tco2  = res['T_each_samp'][0]
# Out:
# c:\Users\PC\Desktop\UIS\Handson\Stand-off\FORWARD
# DEBUG: CO2 iso=1 qfile=TIPS/CO2/q7.txt exists=True
# DEBUG: CO2 iso=2 qfile=TIPS/CO2/q8.txt exists=True
# DEBUG: CO2 iso=3 qfile=TIPS/CO2/q9.txt exists=True
# DEBUG: CO2 iso=4 qfile=TIPS/CO2/q10.txt exists=True
# DEBUG: CO2 iso=5 qfile=TIPS/CO2/q11.txt exists=True
# DEBUG: CO2 iso=6 qfile=TIPS/CO2/q12.txt exists=True
# DEBUG: CO2 iso=7 qfile=TIPS/CO2/q13.txt exists=True
# DEBUG: CO2 iso=8 qfile=TIPS/CO2/q14.txt exists=True
# DEBUG: CO2 iso=9 qfile=TIPS/CO2/q15.txt exists=True
# DEBUG: CO2 iso=10 qfile=TIPS/CO2/q120.txt exists=True
# DEBUG: CO2 iso=A qfile=TIPS/CO2/q121.txt exists=True
# DEBUG: CO2 iso=B qfile=TIPS/CO2/q122.txt exists=True
# c:\Users\PC\Desktop\UIS\Handson\Stand-off\FORWARD\final_forward_attenuation.py:217: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
# ...

# %%
w1 = np.load('SIMULATED/Prueba_Sin_Isotopologos_CO2.npy')
len(w1[0])
# Out:
# 299

# %%
w2 = np.load('SIMULATED/Prueba_Isotopologos_CO2.npy')
len(w2[0])
# Out:
# 299

# %%
np.mean(np.abs(w1[1]-w2[1]))
# Out:
# 0.0003483678832859215
